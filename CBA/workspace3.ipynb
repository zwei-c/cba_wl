# %%
from validation import *

test_data_path = 'datasets/car.data'
test_scheme_path = 'datasets/car.names'
cross_validate_m2_with_prune(test_data_path, test_scheme_path)
# cross_validate_m1_without_prune(test_data_path, test_scheme_path)
# Out:
# buying: {'low': 1, 'vhigh': 2, 'med': 3, 'high': 4}
# maint: {'low': 1, 'vhigh': 2, 'med': 3, 'high': 4}
# doors: {'2': 1, '4': 2, '3': 3, '5more': 4}
# persons: {'more': 1, '4': 2, '2': 3}
# lug_boot: {'med': 1, 'big': 2, 'small': 3}
#
# Round 0:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 189
# CBA-RG's run time with pruning: 1.03 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 11
#
# Round 1:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 173
# CBA-RG's run time with pruning: 0.93 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 8
#
# Round 2:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 178
# CBA-RG's run time with pruning: 0.61 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 10
#
# Round 3:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 187
# CBA-RG's run time with pruning: 0.73 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 11
#
# Round 4:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 181
# CBA-RG's run time with pruning: 0.85 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 11
#
# Round 5:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 196
# CBA-RG's run time with pruning: 1.06 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 11
#
# Round 6:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 170
# CBA-RG's run time with pruning: 0.78 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 1
#
# Round 7:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 184
# CBA-RG's run time with pruning: 0.63 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 11
#
# Round 8:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 190
# CBA-RG's run time with pruning: 0.84 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 1
#
# Round 9:
# CBA's error rate with pruning: 0.0%
# No. of CARs without pruning: 199
# CBA-RG's run time with pruning: 0.60 s
# CBA-CB M2's run time with pruning: 0.05 s
# No. of rules in classifier of CBA-CB M2 with pruning: 1
#
# Average CBA's error rate with pruning: 0.0%
# Average No. of CARs with pruning: 184
# Average CBA-RG's run time with pruning: 0.81 s
# Average CBA-CB M2's run time with pruning: 0.05 s
# Average No. of rules in classifier of CBA-CB M2 with pruning: 7
